# %% [markdown]
# ## Week 3 Assignment: Segmenting and Clustering Neighborhoods in Toronto

# %% [markdown]
# ### *** Start of Part 1 ***

# %% [markdown]
# __1: Converting Wikipedia page to data frame using pandas read_html method__

# %%
import pandas as pd
tables = pd.read_html('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M',flavor='html5lib')
#print(len(tables))
df = tables[0]
df.head()
# Out:
#           0             1                 2
# 0  Postcode       Borough     Neighbourhood
# 1       M1A  Not assigned      Not assigned
# 2       M2A  Not assigned      Not assigned
# 3       M3A    North York         Parkwoods
# 4       M4A    North York  Victoria Village

# %% [markdown]
# __2: Dropping the first row as it is data header and displaying the dimensions__

# %%
df.drop(df.index[0],inplace=True)
df.shape
# Out:
# (289, 3)

# %% [markdown]
# __3: Adding column headers. Only processing the cells that have an assigned borough. Displaying unique Postalcodes,Boroughs and Neighbourhood__

# %%
df.columns = ['PostalCode', 'Borough','Neighbourhood']
#df = df.loc[df['Borough'] != 'Not assigned']
df = df[df.Borough != 'Not assigned'].reset_index(drop=True)

uniquePostCodes = df['PostalCode'].nunique()
uniqueBoroughs = df['Borough'].nunique()
uniqueNeighbourhood= df['Neighbourhood'].nunique()
print('Unique Postalcodes   : {}'.format(uniquePostCodes))
print('Unique Boroughs      : {}'.format(uniqueBoroughs))
print('Unique Neighbourhood : {}'.format(uniqueNeighbourhood))
# Out:
# Unique Postalcodes   : 103
# Unique Boroughs      : 11
# Unique Neighbourhood : 210

# %% [markdown]
# __4: Replace 'Not assigned' neighborhoods with the name of the Borough and print the output before and after updating value__

# %%
df[df['Neighbourhood'] == 'Not assigned'].head()
# Out:
#   PostalCode       Borough Neighbourhood
# 6        M7A  Queen's Park  Not assigned

# %%
# update value with Borough name
df.loc[df['Neighbourhood'] == 'Not assigned', 'Neighbourhood'] = df['Borough']
df.head(10)
# Out:
#   PostalCode           Borough     Neighbourhood
# 0        M3A        North York         Parkwoods
# 1        M4A        North York  Victoria Village
# 2        M5A  Downtown Toronto      Harbourfront
# 3        M5A  Downtown Toronto       Regent Park
# 4        M6A        North York  Lawrence Heights
# 5        M6A        North York    Lawrence Manor
# 6        M7A      Queen's Park      Queen's Park
# 7        M9A         Etobicoke  Islington Avenue
# 8        M1B       Scarborough             Rouge
# 9        M1B       Scarborough           Malvern

# %% [markdown]
# __5: Sort the data frame by postcode, loop through all the rows, compare each row with the next and if postcode matches then combine the two neighbourhoods__

# %%
postalCodesDf = df.sort_values('PostalCode')
postalCodesDf = postalCodesDf.reset_index(drop=True)
postalCodesDf.head()
# Out:
#   PostalCode      Borough   Neighbourhood
# 0        M1B  Scarborough           Rouge
# 1        M1B  Scarborough         Malvern
# 2        M1C  Scarborough      Port Union
# 3        M1C  Scarborough      Rouge Hill
# 4        M1C  Scarborough  Highland Creek

# %%
noOfRows = len(postalCodesDf)-1
n = 0

while n < noOfRows :
    postcode1 = postalCodesDf.iloc[n,0]
    postcode2 = postalCodesDf.iloc[n+1,0]
    neighbourhood1 = postalCodesDf.iloc[n,2]
    neighbourhood2 = postalCodesDf.iloc[n+1,2]

    if postcode1 == postcode2 :
        postalCodesDf.Neighbourhood[n,2] = neighbourhood1+','+neighbourhood2
        postalCodesDf = postalCodesDf.drop(postalCodesDf.index[n+1])
        postalCodesDf = postalCodesDf.reset_index(drop=True)
        noOfRows=noOfRows-1

    else:
        n=n+1

# %%
postalCodesDf
# Out:
#     PostalCode           Borough  \
# 0          M1B       Scarborough
# 1          M1C       Scarborough
# 2          M1E       Scarborough
# 3          M1G       Scarborough
# 4          M1H       Scarborough
# 5          M1J       Scarborough
# 6          M1K       Scarborough
# 7          M1L       Scarborough
# 8          M1M       Scarborough
# 9          M1N       Scarborough
# 10         M1P       Scarborough
# 11         M1R       Scarborough
# 12         M1S       Scarborough
# 13         M1T       Scarborough
# 14         M1V       Scarborough
# 15         M1W       Scarborough
# 16         M1X       Scarborough
# 17         M2H        North York
# 18         M2J        North York
# 19         M2K        North York
# 20         M2L        North York
# 21         M2M        North York
# 22         M2N        North York
# 23         M2P        North York
# 24         M2R        North York
# 25         M3A        North York
# 26         M3B        North York
# ...

# %% [markdown]
# __6: Printing the number of rows in dataframe__

# %%
postalCodesDf.shape
# Out:
# (103, 3)

# %% [markdown]
# ### * END OF PART 1 *

# %% [markdown]
# ### * Start of PART 2 *

# %% [markdown]
# __Pull the geospatial data__

# %%
geoDataDF = pd.read_csv('http://cocl.us/Geospatial_data')
geoDataDF.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %% [markdown]
# __Update the column names and merge the two data sets__

# %%
geoDataDF.columns = ['PostalCode', 'Latitude', 'Longitude']
pcGeoDataDF = pd.merge(postalCodesDf, geoDataDF, on=['PostalCode'], how='inner')
pcGeoDataDF.head()
# Out:
#   PostalCode      Borough                                      Neighbourhood  \
# 0        M1B  Scarborough                                      Rouge,Malvern
# 1        M1C  Scarborough            Rouge,Malvern,Rouge Hill,Highland Creek
# 2        M1E  Scarborough  Beaumond Heights,Humbergate,Jamestown,Mount Ol...
# 3        M1G  Scarborough                                             Woburn
# 4        M1H  Scarborough                                          Cedarbrae
#
#     Latitude  Longitude
# 0  43.806686 -79.194353
# 1  43.784535 -79.160497
# 2  43.763573 -79.188711
# 3  43.770992 -79.216917
# 4  43.773136 -79.239476

# %% [markdown]
# _

# %% [markdown]
# __Creating new dataset with only boroughs that contain the word Toronto__

# %%
torBoroughDF = pcGeoDataDF[pcGeoDataDF['Borough'].str.contains('Toronto')]
torBoroughDF = torBoroughDF.reset_index(drop=True)
torBoroughDF
# Out:
#    PostalCode           Borough  \
# 0         M4E      East Toronto
# 1         M4K      East Toronto
# 2         M4L      East Toronto
# 3         M4M      East Toronto
# 4         M4N   Central Toronto
# 5         M4P   Central Toronto
# 6         M4R   Central Toronto
# 7         M4S   Central Toronto
# 8         M4T   Central Toronto
# 9         M4V   Central Toronto
# 10        M4W  Downtown Toronto
# 11        M4X  Downtown Toronto
# 12        M4Y  Downtown Toronto
# 13        M5A  Downtown Toronto
# 14        M5B  Downtown Toronto
# 15        M5C  Downtown Toronto
# 16        M5E  Downtown Toronto
# 17        M5G  Downtown Toronto
# 18        M5H  Downtown Toronto
# 19        M5J  Downtown Toronto
# 20        M5K  Downtown Toronto
# 21        M5L  Downtown Toronto
# 22        M5N   Central Toronto
# 23        M5P   Central Toronto
# 24        M5R   Central Toronto
# 25        M5S  Downtown Toronto
# 26        M5T  Downtown Toronto
# 27        M5V  Downtown Toronto
# ...

# %% [markdown]
# __Setup Follium and draw the map__

# %%
# !conda install -c conda-forge folium=0.5.0 --yes 
import folium # map rendering library

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values
print('Libraries imported.')
# Out:
# Fetching package metadata .............
# Solving package specifications: .
#
# # All requested packages already installed.
# # packages in environment at /opt/conda/envs/DSX-Python35:
# #
# folium                    0.5.0                      py_0    conda-forge
# Fetching package metadata .............
# Solving package specifications: .
#
# # All requested packages already installed.
# # packages in environment at /opt/conda/envs/DSX-Python35:
# #
# geopy                     1.18.1                     py_0    conda-forge
# Libraries imported.

# %%
address = 'Toronto, Canada'
geolocator = Nominatim()
location = geolocator.geocode(address)
lat = location.latitude
long = location.longitude

mapOfTor = folium.Map(location=[lat, long], zoom_start=12)

# add markers to map
for lat, lng, borough, neighborhood in zip(torBoroughDF['Latitude'], torBoroughDF['Longitude'], torBoroughDF['Borough'], torBoroughDF['Neighbourhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=3,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3b5998',
        fill_opacity=0.4,
        parse_html=False).add_to(mapOfTor)  
    
mapOfTor
# Out:
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/ipykernel/__main__.py:2: DeprecationWarning: Using Nominatim with the default "geopy/1.18.1" `user_agent` is strongly discouraged, as it violates Nominatim's ToS https://operations.osmfoundation.org/policies/nominatim/ and may possibly cause 403 and 429 HTTP errors. Please specify a custom `user_agent` with `Nominatim(user_agent="my-application")` or by overriding the default `user_agent`: `geopy.geocoders.options.default_user_agent = "my-application"`. In geopy 2.0 this will become an exception.
#   from ipykernel import kernelapp as app
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### * End of Part 2 *
